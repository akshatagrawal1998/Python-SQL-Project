# %% [markdown]
# ### Install kaggle library

# %%
# !pip install kaggle
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import kaggle

# %%
# !kaggle datasets download rosennguyen/fitbitfitness-tracker-data-capstone-project -f dailyActivity_merged_cleaned.csv
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/rosennguyen/fitbitfitness-tracker-data-capstone-project
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/109k [00:00<?, ?B/s]
# 100%|##########| 109k/109k [00:00<00:00, 124kB/s]
# 100%|##########| 109k/109k [00:00<00:00, 124kB/s]

# %%
import pandas as pd

# %%
# https://www.kaggle.com/akshatagrawal9431/datasets

# %% [markdown]
# ## To download dataset from Kaggle in Python using Kaggle API:
#
# Prerequisite:
# - You need to have the Kaggle API installed and configured with your Kaggle credentials. This involves having a kaggle.json file that contains your API key and is placed in the appropriate directory (usually ~/.kaggle/).
#
# -- use below command
# !kaggle datasets download akshatagrawal9431/shipment-orders-dataset -f orders_data.csv
#
# - This command is used to download the orders_data.csv file from the shipment-orders-dataset hosted by the user akshatagrawal9431 on Kaggle.
#
# - It typically runs in a Jupyter Notebook or any environment that supports shell commands.

# %%
# !kaggle datasets download akshatagrawal9431/shipment-orders-dataset -f orders_data.csv

# we are downloading dataset from Kaggle using kaggle API
# -f flag specifies a particular file to download from the dataset

# it'll downlaod the data  in zip file, so we'll unzip it next
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/akshatagrawal9431/shipment-orders-dataset
# License(s): CC0-1.0
# orders_data.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ### Unzip the zip file downloaded

# %%
#extract file from zip file

import zipfile
zip_ref = zipfile.ZipFile('orders_data.csv.zip') 
zip_ref.extractall() # extract file to dir

# unzipping the file -> so that the data is extracted then we'll import it 

zip_ref.close() # close file

# %% [markdown]
# ### Reading the csv file after unzipping from zip file

# %%
df=pd.read_csv('orders_data.csv')
df.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  01-03-2023    Second Class   Consumer  United States
# 1         2  15-08-2023    Second Class   Consumer  United States
# 2         3  10-01-2023    Second Class  Corporate  United States
# 3         4  18-06-2022  Standard Class   Consumer  United States
# 4         5  13-07-2022  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df.shape
# Out:
# (9994, 16)

# %%
df.describe()
# Out:
#           Order Id   Postal Code    cost price    List Price     Quantity  \
# count  9994.000000   9994.000000   9994.000000   9994.000000  9994.000000
# mean   4997.500000  55190.379428    201.189714    229.756854     3.789574
# std    2885.163629  32063.693350    537.743203    623.245839     2.225110
# min       1.000000   1040.000000      0.000000      0.000000     1.000000
# 25%    2499.250000  23223.000000     20.000000     20.000000     2.000000
# 50%    4997.500000  56430.500000     50.000000     50.000000     3.000000
# 75%    7495.750000  90008.000000    180.000000    210.000000     5.000000
# max    9994.000000  99301.000000  18110.000000  22640.000000    14.000000
#
#        Discount Percent
# count       9994.000000
# mean           3.484090
# std            1.114211
# min            2.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %% [markdown]
# ### Info of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Id          9994 non-null   int64
#  1   Order Date        9994 non-null   object
#  2   Ship Mode         9993 non-null   object
#  3   Segment           9994 non-null   object
#  4   Country           9994 non-null   object
#  5   City              9994 non-null   object
#  6   State             9994 non-null   object
#  7   Postal Code       9994 non-null   int64
#  8   Region            9994 non-null   object
#  9   Category          9994 non-null   object
#  10  Sub Category      9994 non-null   object
#  11  Product Id        9994 non-null   object
#  12  cost price        9994 non-null   int64
#  13  List Price        9994 non-null   int64
#  14  Quantity          9994 non-null   int64
#  15  Discount Percent  9994 non-null   int64
# dtypes: int64(6), object(10)
# ...

# %% [markdown]
# ### We see that Order Date has object datatype, we need to change it to datetime

# %% [markdown]
# ### Ship mode column has values like Not Available and unknown -> so while reading data from file, we can handle them as NA values

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
# by default it considers few values as NA, but I want to it consider Not-Available, unkowon as NA only

df1 = pd.read_csv('orders_data.csv', na_values=['Not Available', 'unknown'])
df1['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df1.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  01-03-2023    Second Class   Consumer  United States
# 1         2  15-08-2023    Second Class   Consumer  United States
# 2         3  10-01-2023    Second Class  Corporate  United States
# 3         4  18-06-2022  Standard Class   Consumer  United States
# 4         5  13-07-2022  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# ### Derive new columns discount , sale price and profit

# %%
df1.head(2)
# Out:
#    Order Id  Order Date     Ship Mode   Segment        Country       City  \
# 0         1  01-03-2023  Second Class  Consumer  United States  Henderson
# 1         2  15-08-2023  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost price  List Price  Quantity  Discount Percent
# 0         240         260         2                 2
# 1         600         730         3                 3

# %%
df1['Selling_Price'] = df1['List Price'] - df1['List Price']*(df1['Discount Percent']/100)
df1['Selling_Price']
# Out:
# 0       254.8
# 1       708.1
# 2         9.5
# 3       940.8
# 4        19.0
#         ...
# 9989     28.8
# 9990     86.4
# 9991    254.8
# 9992     29.1
# 9993    232.8
# Name: Selling_Price, Length: 9994, dtype: float64

# %%
df1.head(2)
# Out:
#    Order Id  Order Date     Ship Mode   Segment        Country       City  \
# 0         1  01-03-2023  Second Class  Consumer  United States  Henderson
# 1         2  15-08-2023  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost price  List Price  Quantity  Discount Percent  Selling_Price
# 0         240         260         2                 2          254.8
# 1         600         730         3                 3          708.1

# %%
df1['Profit'] = (df1['Selling_Price'] - df1['cost price'])
df1['Profit']
# Out:
# 0        14.8
# 1       108.1
# 2        -0.5
# 3       160.8
# 4        -1.0
#         ...
# 9989     -1.2
# 9990     16.4
# 9991     34.8
# 9992     -0.9
# 9993     22.8
# Name: Profit, Length: 9994, dtype: float64

# %%
df1.head(2)
# Out:
#    Order Id  Order Date     Ship Mode   Segment        Country       City  \
# 0         1  01-03-2023  Second Class  Consumer  United States  Henderson
# 1         2  15-08-2023  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost price  List Price  Quantity  Discount Percent  Selling_Price  Profit
# 0         240         260         2                 2          254.8    14.8
# 1         600         730         3                 3          708.1   108.1

# %%
df1.rename(columns={'Profit' : 'Unit_Profit', 'Selling_Price' : 'Unit_Selling_Price'}, inplace= True)
df1.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  01-03-2023    Second Class   Consumer  United States
# 1         2  15-08-2023    Second Class   Consumer  United States
# 2         3  10-01-2023    Second Class  Corporate  United States
# 3         4  18-06-2022  Standard Class   Consumer  United States
# 4         5  13-07-2022  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df1.dtypes
# Out:
# Order Id                int64
# Order Date             object
# Ship Mode              object
# Segment                object
# Country                object
# City                   object
# State                  object
# Postal Code             int64
# Region                 object
# Category               object
# Sub Category           object
# Product Id             object
# cost price              int64
# List Price              int64
# Quantity                int64
# Discount Percent        int64
# Unit_Selling_Price    float64
# Unit_Profit           float64
# dtype: object

# %% [markdown]
# ### changing datatype of Order Date column from object to datetime

# %%
df1.head(2)
# Out:
#    Order Id  Order Date     Ship Mode   Segment        Country       City  \
# 0         1  01-03-2023  Second Class  Consumer  United States  Henderson
# 1         2  15-08-2023  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost price  List Price  Quantity  Discount Percent  Unit_Selling_Price  \
# 0         240         260         2                 2               254.8
# 1         600         730         3                 3               708.1
#
#    Unit_Profit
# 0         14.8
# 1        108.1

# %%
df1['Order Date'] = pd.to_datetime(df1['Order Date'], format='%d-%m-%Y')

# %%
df1.dtypes
# Out:
# Order Id                       int64
# Order Date            datetime64[ns]
# Ship Mode                     object
# Segment                       object
# Country                       object
# City                          object
# State                         object
# Postal Code                    int64
# Region                        object
# Category                      object
# Sub Category                  object
# Product Id                    object
# cost price                     int64
# List Price                     int64
# Quantity                       int64
# Discount Percent               int64
# Unit_Selling_Price           float64
# Unit_Profit                  float64
# dtype: object

# %%
df1.head()
# Out:
#    Order Id Order Date       Ship Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# ### Dropping few columns

# %%
df1.drop(columns= ['cost price', 'List Price', 'Discount Percent'], inplace=True)

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit
# 0         2               254.8         14.8
# 1         3               708.1        108.1

# %%
# Calculating total profit in each Order
df1['Total Profit'] = df1['Quantity'] * df1['Unit_Profit']

# %%
df1.head()
# Out:
#    Order Id Order Date       Ship Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  Quantity  Unit_Selling_Price  Unit_Profit  \
# 0    Bookcases  FUR-BO-10001798         2               254.8         14.8
# ...

# %%
df.head(5)
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  01-03-2023    Second Class   Consumer  United States
# 1         2  15-08-2023    Second Class   Consumer  United States
# 2         3  10-01-2023    Second Class  Corporate  United States
# 3         4  18-06-2022  Standard Class   Consumer  United States
# 4         5  13-07-2022  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# ## Exporting dataframe to SQL - using SQLALCHEMY library

# %%
import sqlalchemy as sal

# %%
# creating an engine to connect with SQL
# instead of mssql if we are connecting with mysql or postgresql, write them.
# LAPTOP-160PLGFN/project  -> server name
# project-> database name

engine = sal.create_engine('mssql://LAPTOP-160PLGFN/project?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')

# %% [markdown]
# The create_engine function creates an SQLAlchemy Engine object, which establishes a connection to the SQL Server database. The connection string specifies the database type (mssql), the server name (LAPTOP-160PLGFN), the database name (project), and the driver (ODBC DRIVER 17 FOR SQL SERVER).

# %%
conn=engine.connect()
conn

# %%
df1.to_sql('orders_data', con=conn , index=False, if_exists = 'replace')  # or if_exists = 'append'
# Out:
# -1

# %% [markdown]
# This line uses the Pandas to_sql method to write the DataFrame df to the table named orders_data in the SQL Server database. The con parameter specifies the connection object, index=False indicates that the DataFrame's index should not be written as a separate column in the database table, and if_exists='replace' indicates that if the table already exists, it should be replaced. Alternatively, you can use if_exists='append' to add new rows to the existing table.

# %%
df1.head(2)
 #  df.sort_values(by = ['Total Profit'], ascending=False).head(10)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit
# 0         2               254.8         14.8          29.6
# 1         3               708.1        108.1         324.3

# %%
df1.head()
# Out:
#    Order Id Order Date       Ship Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  Quantity  Unit_Selling_Price  Unit_Profit  \
# 0    Bookcases  FUR-BO-10001798         2               254.8         14.8
# ...

# %% [markdown]
# ## Questions:

# %% [markdown]
# ### Q1. Find top 10 highest profit generating products

# %%
df1.groupby('Product Id')

# %%
df1.groupby('Product Id').sum(['Total Profit'])
# Out:
#                  Order Id  Postal Code  Quantity  Unit_Selling_Price  \
# Product Id
# FUR-BO-10000112      3513        60653         9               805.1
# FUR-BO-10000330     13658       256733        10              1036.4
# FUR-BO-10000362     18886       184360        14              2089.4
# FUR-BO-10000468     35749       357215        21               706.1
# FUR-BO-10000711      9310       120635        12               830.9
# ...                   ...          ...       ...                 ...
# TEC-PH-10004912     21739       166396        11               493.8
# TEC-PH-10004922     31470       296048        19              1037.3
# TEC-PH-10004924     13937       105326         8                48.2
# TEC-PH-10004959      5191        83105         4               328.8
# TEC-PH-10004977     49957       473928        32              5099.0
#
#                  Unit_Profit  Total Profit
# Product Id
# FUR-BO-10000112         45.1         405.9
# ...

# %%
df1.groupby('Product Id').sum(['Total Profit']).sort_values(by = ['Total Profit'], ascending=False)
# Out:
#                  Order Id  Postal Code  Quantity  Unit_Selling_Price  \
# Product Id
# TEC-CO-10004722     28222       194875        20             59514.0
# TEC-MA-10002412      2698        32216         6             21734.4
# OFF-BI-10000545     57937       302599        48             18249.0
# TEC-CO-10001449     41444       428939        38             18151.2
# FUR-CH-10002024     44560       448062        39             21096.2
# ...                   ...          ...       ...                 ...
# OFF-BI-10003712     46354       562879        45               124.7
# OFF-AR-10003631     20973       277819        30               106.4
# OFF-PA-10000143     38761       389204        29               153.8
# OFF-BI-10002799     32515       368281        40               114.2
# OFF-FA-10002280     54151       608473        47               251.8
#
#                  Unit_Profit  Total Profit
# Product Id
# TEC-CO-10004722       5644.0       24816.0
# ...

# %%
df1.groupby('Product Id').sum(['Total Profit']).sort_values(by = ['Total Profit'], ascending=False).reset_index()[['Product Id','Total Profit']].head(10)
# Out:
#         Product Id  Total Profit
# 0  TEC-CO-10004722       24816.0
# 1  TEC-MA-10002412       21746.4
# 2  OFF-BI-10000545       17867.7
# 3  TEC-CO-10001449       15948.0
# 4  FUR-CH-10002024       13930.7
# 5  OFF-BI-10003527       12792.9
# 6  TEC-PH-10001459       11481.9
# 7  TEC-MA-10000822       10102.3
# 8  FUR-TA-10000198       10015.1
# 9  TEC-MA-10001047        9989.0

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit
# 0         2               254.8         14.8          29.6
# 1         3               708.1        108.1         324.3

# %% [markdown]
# #### create a column for Total Sales value of each order

# %%
df1['Quantity']
# Out:
# 0       2
# 1       3
# 2       2
# 3       5
# 4       2
#        ..
# 9989    3
# 9990    2
# 9991    2
# 9992    4
# 9993    2
# Name: Quantity, Length: 9994, dtype: int64

# %%
df1['Unit_Selling_Price']
# Out:
# 0       254.8
# 1       708.1
# 2         9.5
# 3       940.8
# 4        19.0
#         ...
# 9989     28.8
# 9990     86.4
# 9991    254.8
# 9992     29.1
# 9993    232.8
# Name: Unit_Selling_Price, Length: 9994, dtype: float64

# %%
df1['Total_Sale'] = df1['Unit_Selling_Price']*df1['Quantity']
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale
# 0         2               254.8         14.8          29.6       509.6
# 1         3               708.1        108.1         324.3      2124.3

# %% [markdown]
# ### Write a Python code to list all distinct cities where orders have been shipped.

# %%
df1.head(1)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale
# 0         2               254.8         14.8          29.6       509.6

# %%
df['City'].unique()

# df['City'].nunique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale
# 0         2               254.8         14.8          29.6       509.6
# 1         3               708.1        108.1         324.3      2124.3

# %% [markdown]
# ### Calculate the total selling price and profits for all orders.

# %%
df1['Order Value'] = df1['Unit_Selling_Price'] * df1['Quantity']
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale  \
# 0         2               254.8         14.8          29.6       509.6
# 1         3               708.1        108.1         324.3      2124.3
#
#    Order Value
# 0        509.6
# 1       2124.3

# %%
df1.groupby('Order Id')

# %%
df1.groupby('Order Id').sum(['Quantity'])
# Out:
#           Postal Code  Quantity  Unit_Selling_Price  Unit_Profit  \
# Order Id
# 1               42420         2               254.8         14.8
# 2               42420         3               708.1        108.1
# 3               90036         2                 9.5         -0.5
# 4               33311         5               940.8        160.8
# 5               33311         2                19.0         -1.0
# ...               ...       ...                 ...          ...
# 9990            33180         3                28.8         -1.2
# 9991            92627         2                86.4         16.4
# 9992            92627         2               254.8         34.8
# 9993            92627         4                29.1         -0.9
# 9994            92683         2               232.8         22.8
#
#           Total Profit  Total_Sale  Order Value
# Order Id
# 1                 29.6       509.6        509.6
# 2                324.3      2124.3       2124.3
# ...

# %%
df1.groupby('Order Id').sum(['Quantity'])[['Order Value', 'Total Profit']]
# Out:
#           Order Value  Total Profit
# Order Id
# 1               509.6          29.6
# 2              2124.3         324.3
# 3                19.0          -1.0
# 4              4704.0         804.0
# 5                38.0          -2.0
# ...               ...           ...
# 9990             86.4          -3.6
# 9991            172.8          32.8
# 9992            509.6          69.6
# 9993            116.4          -3.6
# 9994            465.6          45.6
#
# [9994 rows x 2 columns]

# %%
df1.groupby('Order Id').sum(['Quantity'])[['Order Value', 'Total Profit']].reset_index()
# Out:
#       Order Id  Order Value  Total Profit
# 0            1        509.6          29.6
# 1            2       2124.3         324.3
# 2            3         19.0          -1.0
# 3            4       4704.0         804.0
# 4            5         38.0          -2.0
# ...        ...          ...           ...
# 9989      9990         86.4          -3.6
# 9990      9991        172.8          32.8
# 9991      9992        509.6          69.6
# 9992      9993        116.4          -3.6
# 9993      9994        465.6          45.6
#
# [9994 rows x 3 columns]

# %%
df1.groupby('Order Id').sum(['Quantity'])[['Order Value', 'Total Profit']].reset_index().sort_values(by = ['Total Profit'], ascending = False)
# Out:
#       Order Id  Order Value  Total Profit
# 2697      2698     130406.4       21746.4
# 6826      6827      84875.0       14875.0
# 9039      9040     122141.5       12811.5
# 4277      4278      61789.0        8309.0
# 165        166      62668.8        7868.8
# ...        ...          ...           ...
# 7929      7930       1710.0         -30.0
# 4579      4580        739.2         -30.8
# 2567      2568      22828.5         -31.5
# 9121      9122        598.5         -31.5
# 3668      3669        960.0         -40.0
#
# [9994 rows x 3 columns]

# %% [markdown]
# ### Find all orders from the 'Technology' category that were shipped using 'Second Class' ship mode, ordered by order date

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale
# 0         2               254.8         14.8          29.6       509.6
# 1         3               708.1        108.1         324.3      2124.3

# %%
df1[(df1['Category'] == 'Technology') & (df1['Ship Mode'] == 'Second Class')]
# Out:
#       Order Id Order Date     Ship Mode      Segment        Country  \
# 19          20 2022-01-11  Second Class     Consumer  United States
# 26          27 2022-02-08  Second Class     Consumer  United States
# 161        162 2023-11-27  Second Class     Consumer  United States
# 181        182 2022-06-25  Second Class    Corporate  United States
# 182        183 2022-01-10  Second Class  Home Office  United States
# ...        ...        ...           ...          ...            ...
# 9891      9892 2023-05-21  Second Class    Corporate  United States
# 9892      9893 2023-01-02  Second Class    Corporate  United States
# 9949      9950 2022-01-07  Second Class    Corporate  United States
# 9950      9951 2022-03-19  Second Class    Corporate  United States
# 9960      9961 2023-02-26  Second Class  Home Office  United States
#
#                City         State  Postal Code   Region    Category  \
# 19    San Francisco    California        94109     West  Technology
# ...

# %%
df1[(df1['Category'] == 'Technology') & (df1['Ship Mode'] == 'Second Class')]

# %% [markdown]
# ### Find the average order value

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale
# 0         2               254.8         14.8          29.6       509.6
# 1         3               708.1        108.1         324.3      2124.3

# %%
import numpy as np
np.mean(df1['Total_Sale'])
# Out:
# 1108.5979787872725

# %% [markdown]
# ### Find the city with the highest total quantity of products ordered.

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale
# 0         2               254.8         14.8          29.6       509.6
# 1         3               708.1        108.1         324.3      2124.3

# %%
df1.groupby('City').sum('Quantity')['Quantity'].reset_index().sort_values(by = ['Quantity'], ascending=ending = False)
# Out:
#               City  Quantity
# 329  New York City      3417
# 266    Los Angeles      2879
# 374   Philadelphia      1981
# 438  San Francisco      1935
# 452        Seattle      1590
# ..             ...       ...
# 213      Iowa City         1
# 386    Port Orange         1
# 257    Lindenhurst         1
# 259      Littleton         1
# 140         Elyria         1
#
# [531 rows x 2 columns]

# %%
df1.groupby('City').sum('Qunatity')['Quantity'].reset_index().sort_values(by = ['Quantity'], ascending = False)
# Out:
#               City  Quantity
# 329  New York City      3417
# 266    Los Angeles      2879
# 374   Philadelphia      1981
# 438  San Francisco      1935
# 452        Seattle      1590
# ..             ...       ...
# 213      Iowa City         1
# 386    Port Orange         1
# 257    Lindenhurst         1
# 259      Littleton         1
# 140         Elyria         1
#
# [531 rows x 2 columns]

# %%
df1[df1['Order Id'] == 6489]

# %% [markdown]
# ### rank orders in each region by quantity in descending order

# %%
df1[['Order Id', 'Region', 'Quantity']].sort_values(by = ['Region', 'Quantity'], ascending = [True, False])
# Out:
#       Order Id   Region  Quantity
# 660        661  Central        14
# 1045      1046  Central        14
# 7387      7388  Central        14
# 8074      8075  Central        14
# 9515      9516  Central        14
# ...        ...      ...       ...
# 9752      9753     West         1
# 9838      9839     West         1
# 9902      9903     West         1
# 9953      9954     West         1
# 9986      9987     West         1
#
# [9994 rows x 3 columns]

# %% [markdown]
# ### list all orders placed in the first quarter of any year (January to March), including the total cost for these orders

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale
# 0         2               254.8         14.8          29.6       509.6
# 1         3               708.1        108.1         324.3      2124.3

# %%
df1['Order Date'].dt.month
# Out:
# 0        3
# 1        8
# 2        1
# 3        6
# 4        7
#         ..
# 9989     2
# 9990     3
# 9991     8
# 9992    11
# 9993     7
# Name: Order Date, Length: 9994, dtype: int32

# %%
df1['Month'] = df1['Order Date'].dt.month
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale  Month
# 0         2               254.8         14.8          29.6       509.6      3
# 1         3               708.1        108.1         324.3      2124.3      8

# %%
df1[df1['Month'].isin([1,2,3])]
# Out:
#       Order Id Order Date       Ship Mode      Segment        Country  \
# 0            1 2023-03-01    Second Class     Consumer  United States
# 2            3 2023-01-10    Second Class    Corporate  United States
# 5            6 2022-03-13             NaN     Consumer  United States
# 7            8 2022-01-25  Standard Class     Consumer  United States
# 8            9 2023-03-23             NaN     Consumer  United States
# ...        ...        ...             ...          ...            ...
# 9963      9964 2022-01-17        Same Day     Consumer  United States
# 9966      9967 2022-02-21    Second Class    Corporate  United States
# 9973      9974 2023-03-07  Standard Class  Home Office  United States
# 9989      9990 2023-02-18    Second Class     Consumer  United States
# 9990      9991 2023-03-17  Standard Class     Consumer  United States
#
#               City         State  Postal Code Region         Category  \
# ...

# %%
# Alternative

df1['Quarter'] = df1['Order Date'].dt.quarter
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale  Month  \
# 0         2               254.8         14.8          29.6       509.6      3
# 1         3               708.1        108.1         324.3      2124.3      8
#
#    Quarter
# 0        1
# 1        3

# %%
df1[df1['Order Date'].dt.quarter.isin([1])]  #['Order Id']
# Out:
#       Order Id Order Date       Ship Mode      Segment        Country  \
# 0            1 2023-03-01    Second Class     Consumer  United States
# 2            3 2023-01-10    Second Class    Corporate  United States
# 5            6 2022-03-13             NaN     Consumer  United States
# 7            8 2022-01-25  Standard Class     Consumer  United States
# 8            9 2023-03-23             NaN     Consumer  United States
# ...        ...        ...             ...          ...            ...
# 9963      9964 2022-01-17        Same Day     Consumer  United States
# 9966      9967 2022-02-21    Second Class    Corporate  United States
# 9973      9974 2023-03-07  Standard Class  Home Office  United States
# 9989      9990 2023-02-18    Second Class     Consumer  United States
# 9990      9991 2023-03-17  Standard Class     Consumer  United States
#
#               City         State  Postal Code Region         Category  \
# ...

# %%
df1['year'] = df1['Order Date'].dt.year
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale  Month  \
# 0         2               254.8         14.8          29.6       509.6      3
# 1         3               708.1        108.1         324.3      2124.3      8
#
#    Quarter  year
# 0        1  2023
# 1        3  2023

# %%
temp_df =  df1.groupby(['year','Quarter']).sum('Total_Sale')['Total_Sale'].reset_index()
temp_df
# Out:
#    year  Quarter  Total_Sale
# 0  2022        1   1275547.6
# 1  2022        2   1355326.7
# 2  2022        3   1343727.8
# 3  2022        4   1500939.2
# 4  2023        1   1559456.2
# 5  2023        2   1282878.4
# 6  2023        3   1308164.5
# 7  2023        4   1453287.8

# %%
temp_df[temp_df['Quarter'] == 1]
# Out:
#    year  Quarter  Total_Sale
# 0  2022        1   1275547.6
# 4  2023        1   1559456.2

# %% [markdown]
# ### Find top 10 highest profit generating products

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale  Month  \
# 0         2               254.8         14.8          29.6       509.6      3
# 1         3               708.1        108.1         324.3      2124.3      8
#
#    Quarter  year
# 0        1  2023
# 1        3  2023

# %%
df1.groupby('Product Id').sum(['Total Profit'])['Total Profit'].reset_index().sort_values(by = 'Total Profit', ascending = False).head(10)


#  now the question couuld also be for top products acc to revenue/sales.
# Out:
#            Product Id  Total Profit
# 1614  TEC-CO-10004722       24816.0
# 1642  TEC-MA-10002412       21746.4
# 657   OFF-BI-10000545       17867.7
# 1604  TEC-CO-10001449       15948.0
# 80    FUR-CH-10002024       13930.7
# 776   OFF-BI-10003527       12792.9
# 1724  TEC-PH-10001459       11481.9
# 1624  TEC-MA-10000822       10102.3
# 318   FUR-TA-10000198       10015.1
# 1630  TEC-MA-10001047        9989.0

# %% [markdown]
# ### Find top 3 highest selling products in each region acc to quantity

# %%
df1.groupby(['Region', 'Product Id']).sum('Quantity')['Quantity'].reset_index()
# Out:
#        Region       Product Id  Quantity
# 0     Central  FUR-BO-10000112         9
# 1     Central  FUR-BO-10000362         3
# 2     Central  FUR-BO-10000468         4
# 3     Central  FUR-BO-10000711         3
# 4     Central  FUR-BO-10000780        17
# ...       ...              ...       ...
# 5293     West  TEC-PH-10004896         3
# 5294     West  TEC-PH-10004897         3
# 5295     West  TEC-PH-10004908        22
# 5296     West  TEC-PH-10004922         9
# 5297     West  TEC-PH-10004977        10
#
# [5298 rows x 3 columns]

# %%
x = df1.groupby(['Region', 'Product Id']).sum('Quantity')['Quantity'].reset_index().sort_values(by = ['Region', 'Quantity'], ascending = [True, False])
x
# Out:
#        Region       Product Id  Quantity
# 461   Central  OFF-BI-10000301        34
# 474   Central  OFF-BI-10000756        33
# 470   Central  OFF-BI-10000546        29
# 491   Central  OFF-BI-10001249        29
# 61    Central  FUR-CH-10002304        27
# ...       ...              ...       ...
# 5219     West  TEC-PH-10002185         1
# 5227     West  TEC-PH-10002447         1
# 5229     West  TEC-PH-10002483         1
# 5256     West  TEC-PH-10003357         1
# 5276     West  TEC-PH-10004120         1
#
# [5298 rows x 3 columns]

# %%
x.groupby('Region').head(3).reset_index()

# %%
df1.head(2)

# %% [markdown]
# ### total sale in each region

# %%
df1.groupby('Region').sum(['Total_Sale'])['Total_Sale'].reset_index().sort_values(by = ['Total_Sale'], ascending = False)
# Out:
#     Region  Total_Sale
# 3     West   3467409.6
# 1     East   3257983.8
# 0  Central   2387881.2
# 2    South   1966053.6

# %% [markdown]
# ### Find top 5 highest selling products in each region according to sales

# %%
df1.groupby(['Region', 'Product Id']).sum(['Total_Sale'])  #.sort_values(by = ['Total_Sale'],ascending=False)

# %%
df1.groupby(['Region', 'Product Id']).sum(['Total_Sale']).reset_index()

# %%
x = df1.groupby(['Region', 'Product Id']).sum(['Total_Sale'])['Total_Sale'].reset_index()
y = x.sort_values(by = ['Region', 'Total_Sale'], ascending=[True, False])
y.groupby('Region').head(5).reset_index()

# %%
x.sort_values(by = ['Region', 'Total_Sale'], ascending=[True, False])

# %%
df.head(2)

# %% [markdown]
# ### Find month over month growth comparison for 2022 and 2023 sales eg : jan 2022 vs jan 2023

# %%
df1['Month'] = df['Order Date'].dt.month
df1['Month']

# %%
df1['Year'] = df['Order Date'].dt.year
df1['Year']

# %%
df1.head(2)
# Out:
#    Order Id Order Date     Ship Mode   Segment        Country       City  \
# 0         1 2023-03-01  Second Class  Consumer  United States  Henderson
# 1         2 2023-08-15  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    Quantity  Unit_Selling_Price  Unit_Profit  Total Profit  Total_Sale  Month  \
# 0         2               254.8         14.8          29.6       509.6      3
# 1         3               708.1        108.1         324.3      2124.3      8
#
#    Quarter  year
# 0        1  2023
# 1        3  2023

# %%
df1.groupby(['Month', 'year'])

# %%
df1.groupby(['Month', 'year']).sum('Total_Sale')
# Out:
#             Order Id  Postal Code  Quantity  Unit_Selling_Price  Unit_Profit  \
# Month year
# 1     2022   2203269     25254924      1650             94712.5       9092.5
#       2023   2159265     22745269      1543             88632.6       8272.6
# 2     2022   1942952     21548462      1511             90091.0       9101.0
#       2023   1963083     21939004      1574            128124.2      11554.2
# 3     2022   2001085     20660876      1447             80106.0       7076.0
#       2023   2204143     23815029      1651             82512.3       7642.3
# 4     2022   2214787     25361800      1648             95451.6       8801.6
#       2023   1941539     22098149      1501            111568.6      10028.6
# 5     2022   2076080     23908332      1639             79448.3       7088.3
#       2023   2038723     23553002      1561             86447.9       8187.9
# 6     2022   1967618     21814012      1528             94170.5       8300.5
# ...

# %%
df1.groupby(['Month', 'year']).sum('Total_Sale')['Total_Sale']
# Out:
# Month  year
# 1      2022    437431.3
#        2023    434765.5
# 2      2022    444011.1
#        2023    731638.8
# 3      2022    394105.2
#        2023    393051.9
# 4      2022    476400.9
#        2023    543231.5
# 5      2022    413625.5
#        2023    410707.9
# 6      2022    465300.3
#        2023    328939.0
# 7      2022    375278.4
#        2023    422533.7
# 8      2022    534562.4
#        2023    465010.3
# 9      2022    433887.0
#        2023    420620.5
# 10     2022    601707.8
#        2023    626498.3
# 11     2022    451809.6
#        2023    334940.6
# 12     2022    447421.8
#        2023    491848.9
# Name: Total_Sale, dtype: float64

# %%
a = df1.groupby(['Month', 'year']).sum('Total_Sale')['Total_Sale'].reset_index()
a
# Out:
#     Month  year  Total_Sale
# 0       1  2022    437431.3
# 1       1  2023    434765.5
# 2       2  2022    444011.1
# 3       2  2023    731638.8
# 4       3  2022    394105.2
# 5       3  2023    393051.9
# 6       4  2022    476400.9
# 7       4  2023    543231.5
# 8       5  2022    413625.5
# 9       5  2023    410707.9
# 10      6  2022    465300.3
# 11      6  2023    328939.0
# 12      7  2022    375278.4
# 13      7  2023    422533.7
# 14      8  2022    534562.4
# 15      8  2023    465010.3
# 16      9  2022    433887.0
# 17      9  2023    420620.5
# 18     10  2022    601707.8
# 19     10  2023    626498.3
# 20     11  2022    451809.6
# 21     11  2023    334940.6
# 22     12  2022    447421.8
# 23     12  2023    491848.9

# %%
pivot_table = a.pivot_table(index='Month', columns='year', values='Total_Sale', aggfunc='sum')
pivot_table
# Out:
# year       2022      2023
# Month
# 1      437431.3  434765.5
# 2      444011.1  731638.8
# 3      394105.2  393051.9
# 4      476400.9  543231.5
# 5      413625.5  410707.9
# 6      465300.3  328939.0
# 7      375278.4  422533.7
# 8      534562.4  465010.3
# 9      433887.0  420620.5
# 10     601707.8  626498.3
# 11     451809.6  334940.6
# 12     447421.8  491848.9

# %%
pivot_table = pivot_table.reset_index()
pivot_table
# Out:
# year  Month      2022      2023
# 0         1  437431.3  434765.5
# 1         2  444011.1  731638.8
# 2         3  394105.2  393051.9
# 3         4  476400.9  543231.5
# 4         5  413625.5  410707.9
# 5         6  465300.3  328939.0
# 6         7  375278.4  422533.7
# 7         8  534562.4  465010.3
# 8         9  433887.0  420620.5
# 9        10  601707.8  626498.3
# 10       11  451809.6  334940.6
# 11       12  447421.8  491848.9

# %%
pivot_table['YoY_growth'] = pivot_table[2022] - pivot_table[2023]
pivot_table

# similarly we can calculate % also
# Out:
# year  Month      2022      2023  YoY_growth
# 0         1  437431.3  434765.5      2665.8
# 1         2  444011.1  731638.8   -287627.7
# 2         3  394105.2  393051.9      1053.3
# 3         4  476400.9  543231.5    -66830.6
# 4         5  413625.5  410707.9      2917.6
# 5         6  465300.3  328939.0    136361.3
# 6         7  375278.4  422533.7    -47255.3
# 7         8  534562.4  465010.3     69552.1
# 8         9  433887.0  420620.5     13266.5
# 9        10  601707.8  626498.3    -24790.5
# 10       11  451809.6  334940.6    116869.0
# 11       12  447421.8  491848.9    -44427.1

# %%
df1.head(2)

# %%
df1['Month-Year'] = df1['Order Date'].dt.strftime('%Y-%m')
df.head(2)

# %% [markdown]
# ### For each category which month had highest sales

# %%
df.head(2).groupby(['Month-Year', 'Category']).sum(['Total_Sale'])['Total_Sale'].reset_index()

# %%
b = df1.groupby(['Category', 'Month-Year']).sum(['Total_Sale'])['Total_Sale'].reset_index()
b

# %%
c = b.sort_values(by = ['Category', 'Total_Sale'], ascending=[True, False])
c

# %%
c.groupby('Category').head(1)

# %%
df1.head(2)

# %% [markdown]
# ### Which sub category had highest growth by profit in 2023 compare to 2022

# %%
m = df1.groupby(['Sub Category', 'Year']).sum(['Total Profit'])['Total Profit'].reset_index()
m

# %%
n = m.pivot_table(index = 'Sub Category', columns='Year', values = 'Total Profit').reset_index()
n.head()

# %%
n['diff'] = n[2023] - n[2022]

n.sort_values(by = ['diff'], ascending=False).head(1)

# %% [markdown]
# ## Let's build SQL connection to get data from Pandas dataframe into SQL

# %%
df.head(2)
# Out:
#    Order Id  Order Date     Ship Mode   Segment        Country       City  \
# 0         1  01-03-2023  Second Class  Consumer  United States  Henderson
# 1         2  15-08-2023  Second Class  Consumer  United States  Henderson
#
#       State  Postal Code Region   Category Sub Category       Product Id  \
# 0  Kentucky        42420  South  Furniture    Bookcases  FUR-BO-10001798
# 1  Kentucky        42420  South  Furniture       Chairs  FUR-CH-10000454
#
#    cost price  List Price  Quantity  Discount Percent
# 0         240         260         2                 2
# 1         600         730         3                 3

# %%
import sqlalchemy as sal
engine = sal.create_engine('mssql://LAPTOP-160PLGFN/project?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')

conn=engine.connect()

df.to_sql('order_data', con=conn , index=False, if_exists = 'replace')  # or if_exists = 'append'
# Out:
# -1

# %%
try:
    df.to_sql('orders_data', con=conn, index=False, if_exists='replace')
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ## Reading data from SQL Server in Python

# %%
# Windows authentication

import pyodbc

# Properly formatted connection string
cnxn = pyodbc.connect(
    r'Driver={SQL Server Native Client 11.0};'
    r'Server=LAPTOP-160PLGFN;' 
    r'Trusted_Connection=yes;'
    r'Database=project;'
)

# %%
df = pd.read_sql_query('select * from orders_data', cnxn)
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_83388\1084758224.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query('select * from orders_data', cnxn)
#    Order Id Order Date       Ship Mode    Segment        Country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.shape
